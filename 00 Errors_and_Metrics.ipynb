# %% [markdown]
# <a href="https://colab.research.google.com/github/a-forty-two/GAIP_22_June/blob/main/00%20Errors_and_Metrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# input-> dataset
# identify-> Input Features (X) and Output Label (Y)
# output-> after ML-> ML Equation 
# y=mx + c-> regression 
# y<=mx + c; y> mx+c-> binary classification
# usage-> ML equation-> PREDICT the values

# %%
# divide-> training and scoring 
# training-> to teach the model
# scoring-> to test the model

# %%
# once the model is ready-> predictions P emerging out of equation

# the difference between our known results (from Score dataset)
# and the predictions P is called ERROR

# %%
# ytest = [0,1,0,1,-1,-1]
# P = [0,-1,0,-1,1,1]
# difference between ytest and P
# ytest-P = [ 0-0, 1-(-1), 0-0, 1-(-1), -1-(+1), -1-(+1) ]
# ytest-P = [0, 2, 0, 2, -2, -2]
# total error= 0+2+0+2-2-2?
# Does this mean my total error was 0?

# %%
# Zero Error is impossible and it has ALREADY been observed that
# our error is most surely not NULL!

# %%
# 2 approaches
# 1st- Absolute Values
# 2nd- Square the Values

# %%
# 1st Absolute Values
# ytest = [0,1,0,1,-1,-1]
# P = [0,-1,0,-1,1,1]
# ytest_abs = | ytest - P | = [0, 2, 0, 2 , 2, 2]
# Absolute Error= 0+2+0+2+2+2 = 8
# Mean Absolute Error= absolute error/N = 8/6 = 1.3333
# 7X1 = 7 +- 1.3333

# %%
# Square the values
# ytest = [0,1,0,1,-1,-1]
# P = [0,-1,0,-1,1,1]
# Squared Errors = [0, 4, 0, 4, 4, 4]
# Total Suquared Errors = 16
# Mean Squared Error = TotalSquaredError/N = 16/6 = 2.666
# Root Mean Squared Error = root(MeanSquaredError)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

ytest = [0,1,0,1,-1,-1]
P = [0,-1,0,-1,1,1]

# %%
mean_absolute_error(ytest, P)
# Out:
# 1.3333333333333333

# %%
mean_squared_error(ytest, P)
# Out:
# 2.6666666666666665

# %%
# root mean squared error
mean_squared_error(ytest,P, squared=False)
# Out:
# 1.632993161855452

# %%
# numbers-> represent just a CLASS and not absolute value
# in such cases, class 2 is just diff from class 1
# 2 is NOT >= 1

# %%
# Accuracy = Correct Guesses/Total Guesses
ytest = [0,1,0,1,1,1]
P = [0,1,1,1,1,0]
# total correct guesses = 4
# total guesses = 6
# accuracy = 4/6 = 0.6666

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('StandardDeviation.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=2046x980 at 0x7FE4FCBA6E10>

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/a-forty-two/diamler_17_jan/main/train.csv', header=0)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
data.describe().T
# Out:
#              count        mean         std  ...       50%    75%       max
# PassengerId  891.0  446.000000  257.353842  ...  446.0000  668.5  891.0000
# Survived     891.0    0.383838    0.486592  ...    0.0000    1.0    1.0000
# Pclass       891.0    2.308642    0.836071  ...    3.0000    3.0    3.0000
# Age          714.0   29.699118   14.526497  ...   28.0000   38.0   80.0000
# SibSp        891.0    0.523008    1.102743  ...    0.0000    1.0    8.0000
# Parch        891.0    0.381594    0.806057  ...    0.0000    0.0    6.0000
# Fare         891.0   32.204208   49.693429  ...   14.4542   31.0  512.3292
#
# [7 rows x 8 columns]

# %%
stats = data.describe().T
stats['std']
# Most of your values should be about->
# (mean + std) to (mean - std)
# Out:
# PassengerId    257.353842
# Survived         0.486592
# Pclass           0.836071
# Age             14.526497
# SibSp            1.102743
# Parch            0.806057
# Fare            49.693429
# Name: std, dtype: float64

# %%
stats = data.describe().T
stats[['mean','std','min','25%','75%','max']]
# Out:
#                    mean         std   min       25%    75%       max
# PassengerId  446.000000  257.353842  1.00  223.5000  668.5  891.0000
# Survived       0.383838    0.486592  0.00    0.0000    1.0    1.0000
# Pclass         2.308642    0.836071  1.00    2.0000    3.0    3.0000
# Age           29.699118   14.526497  0.42   20.1250   38.0   80.0000
# SibSp          0.523008    1.102743  0.00    0.0000    1.0    8.0000
# Parch          0.381594    0.806057  0.00    0.0000    0.0    6.0000
# Fare          32.204208   49.693429  0.00    7.9104   31.0  512.3292

# %%
# !ls
# Out:
#  sample_data
# 'Screen Shot 2022-01-24 at 12.46.22 PM.png'
# 'Screen Shot 2022-01-24 at 12.46.29 PM.png'
#  StandardDeviation.png

# %%
# Central Limit Theorem-> 
# Most of your data-> innermost circle
# 98-99% of your data-> 2x of STD
# 99%-99.99%-> within 3x of STD
# ANYTHING more-> OUTLIER, removed from dataset OR adjusted to max/min value!

# %%
# TOP view of Central Limit Theorem

# %% [markdown]
# ![Screen Shot 2022-01-24 at 12.46.22 PM.png](data:image/png;base64,...)

# %%
# Side view of Central Limit Theorem

# %% [markdown]
# ![Screen Shot 2022-01-24 at 12.46.29 PM.png](data:image/png;base64,...)
